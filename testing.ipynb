# %%
import pandas as pd
import datetime

# %%
#X = input(print("Whats the name of the file that you want to convert? (include the .csv at the end) "))
# Out:
# Whats the name of the file that you want to convert? (include the .csv at the end)
# NoneHotel Reservations.csv

# %%
Y = input(print("Whats the name of the relevant column? (watch out for lower- and upper-case) "))
# Out:
# Whats the name of the relevant column? (watch out for lower- and upper-case)
# Nonetype_of_meal_plan

# %%
Y
# Out:
# 'type_of_meal_plan'

# %%
df = pd.read_csv("Hotel Reservations.csv")

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.columns = str.lower()
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [104], line 1
# ----> 1 df.columns = df.columns.lowercase()
#       2 df.columns
#
# AttributeError: 'Index' object has no attribute 'lowercase'

# %%
options = df[Y].unique()
options
# Out:
# array(['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3'],
#       dtype=object)

# %%
options[0]
# Out:
# 'Meal Plan 1'

# %%
len(options)
# Out:
# 4

# %%
df_name = "hi"

# %%
start = 0
list_names = []
for i in options:
    name = f"Convert{start}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}"
    temp = df[df[Y] == options[start]]
    #exec(f"{name} = df[df[Y] == options[start]]")
    temp.to_excel(f"{name}.xlsx", index=False)
    print(f"{name}.xlsx")
    print(options[start])
    start = start + 1
# Out:
# Convert0_2023-02-10_00-42-28.xlsx
# Meal Plan 1
# Convert1_2023-02-10_00-42-35.xlsx
# Not Selected
# Convert2_2023-02-10_00-42-36.xlsx
# Meal Plan 2
# Convert3_2023-02-10_00-42-37.xlsx
# Meal Plan 3

# %%
df.to_excel("dataframe.xlsx", index=False)

# %%
meal_plan_1 = df[df["type_of_meal_plan"] == "Meal Plan 1"]

# %%
meal_plan_1
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 6       INN00007             2               0                     1
# 7       INN00008             2               0                     1
# ...          ...           ...             ...                   ...
# 36269   INN36270             2               2                     0
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                      2       Meal Plan 1                           0
# 2                      1       Meal Plan 1                           0
# 3                      2       Meal Plan 1                           0
# 6                      3       Meal Plan 1                           0
# 7                      3       Meal Plan 1                           0
# ...                  ...               ...                         ...
# 36269                  1       Meal Plan 1                           0
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# 0            Room_Type 1        224          2017             10
# 2            Room_Type 1          1          2018              2
# 3            Room_Type 1        211          2018              5
# 6            Room_Type 1         34          2017             10
# 7            Room_Type 4         83          2018             12
# ...                  ...        ...           ...            ...
# 36269        Room_Type 6          0          2018             10
# 36270        Room_Type 4         85          2018              8
# 36271        Room_Type 1        228          2018             10
# 36272        Room_Type 1        148          2018              7
# 36274        Room_Type 1        207          2018             12
#
#        arrival_date market_segment_type  repeated_guest  \
# 0                 2             Offline               0
# 2                28              Online               0
# 3                20              Online               0
# 6                15              Online               0
# 7                26              Online               0
# ...             ...                 ...             ...
# 36269             6              Online               0
# 36270             3              Online               0
# 36271            17              Online               0
# 36272             1              Online               0
# 36274            30             Offline               0
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# 0                                 0                                     0
# 2                                 0                                     0
# 3                                 0                                     0
# 6                                 0                                     0
# 7                                 0                                     0
# ...                             ...                                   ...
# 36269                             0                                     0
# 36270                             0                                     0
# 36271                             0                                     0
# 36272                             0                                     0
# 36274                             0                                     0
#
#        avg_price_per_room  no_of_special_requests booking_status
# 0                   65.00                       0   Not_Canceled
# 2                   60.00                       0       Canceled
# 3                  100.00                       0       Canceled
# 6                  107.55                       1   Not_Canceled
# 7                  105.61                       1   Not_Canceled
# ...                   ...                     ...            ...
# 36269              216.00                       0       Canceled
# 36270              167.80                       1   Not_Canceled
# 36271               90.95                       2       Canceled
# 36272               98.39                       2   Not_Canceled
# 36274              161.67                       0   Not_Canceled
#
# [27835 rows x 19 columns]
